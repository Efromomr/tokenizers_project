# %%
# !pip install -q sentencepiece
# !pip install -q transformers
# !pip install -q pyspellchecker
# !pip install -q pyngrok
# !pip install -q gdown
# !pip install -q Flask
# !pip install -q transformers
# !pip install -q datasets
# !pip install -q torch
# !pip install -q tokenizers
# !pip install -q pandas
# !pip install -q jieba
# !pip install -q pytextspan
# !pip install -q mecab-python3
# !pip install -q pyarabic
# !pip install -q botocore
# !pip install -q cached_path
# !pip install -q scikit-learn==1.5.2
# !pip install -q accelerate
# !pip install -q konlpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.7/581.7 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 108.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytensor 2.26.3 requires filelock>=3.15, but you have filelock 3.13.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 94.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.8/493.8 kB 35.8 MB/s eta 0:00:00

# %%
from pyngrok import ngrok

# %%
# !ngrok config add-authtoken 'ТОКЕН ДЛЯ ngrok'
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import os

# %%
# !gdown --id 1CxsFiCm60QXHUw6Xy5uMWW0btBINsiIh -O file.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1CxsFiCm60QXHUw6Xy5uMWW0btBINsiIh
# To: /content/file.zip
# 100% 22.6k/22.6k [00:00<00:00, 67.5MB/s]

# %%
# !unzip file.zip
# Out:
# Archive:  file.zip
#    creating: pipeline/
#    creating: pipeline/alltoks/
#   inflating: pipeline/alltoks/tokenizer_pretrain.py
#   inflating: pipeline/alltoks/__init__.py
#    creating: pipeline/alltoks/__pycache__/
#   inflating: pipeline/alltoks/__pycache__/custom_tokenizers.cpython-310.pyc
#   inflating: pipeline/alltoks/__pycache__/tokenizer_pretrain.cpython-310.pyc
#   inflating: pipeline/alltoks/__pycache__/__init__.cpython-310.pyc
#   inflating: pipeline/alltoks/custom_tokenizers.py
#   inflating: pipeline/app.py
#    creating: pipeline/data/
#   inflating: pipeline/data/chinese_small.csv
#   inflating: pipeline/data/dataset_preprocessing.py
#   inflating: pipeline/data/__init__.py
#    creating: pipeline/data/__pycache__/
#   inflating: pipeline/data/__pycache__/dataset_preprocessing.cpython-310.pyc
#   inflating: pipeline/data/__pycache__/__init__.cpython-310.pyc
#   inflating: pipeline/main.py
#    creating: pipeline/models/
#   inflating: pipeline/models/bert_config.py
#   inflating: pipeline/models/__init__.py
#    creating: pipeline/models/__pycache__/
#   inflating: pipeline/models/__pycache__/bert_config.cpython-310.pyc
#   inflating: pipeline/models/__pycache__/__init__.cpython-310.pyc
#   inflating: pipeline/requirements.txt
#    creating: pipeline/templates/
#   inflating: pipeline/templates/tokenize.html
#   inflating: pipeline/templates/base.html
#   inflating: pipeline/templates/index.html
#    creating: pipeline/utils/
#   inflating: pipeline/utils/helpers.py
#   inflating: pipeline/utils/__init__.py
#    creating: pipeline/utils/__pycache__/
#   inflating: pipeline/utils/__pycache__/helpers.cpython-310.pyc
#   inflating: pipeline/utils/__pycache__/__init__.cpython-310.pyc
#    creating: pipeline/__pycache__/
#   inflating: pipeline/__pycache__/main.cpython-310.pyc

# %%
cd pipeline/
# Out:
# /content/pipeline

# %%
# %run app.py
# Out:
# Сервер доступен по адресу: NgrokTunnel: "https://bcbf-34-16-149-114.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app 'app'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [29/Nov/2024 00:51:20] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [29/Nov/2024 00:51:21] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [29/Nov/2024 00:51:35] "GET /tokenize HTTP/1.1" 200 -
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:12, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Parameter 'function'=<function preprocess_dataset.<locals>.<lambda> at 0x7b3f7324dab0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function preprocess_dataset.<locals>.<lambda> at 0x7b3f7324dab0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:08, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:09, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:08, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:21, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# INFO:werkzeug:127.0.0.1 - - [29/Nov/2024 00:54:08] "POST /tokenize HTTP/1.1" 200 -
#         tokenizer      metric         score
# 0             wpe  perplexity  74166.117747
# 1      wpe_custom  perplexity  14370.876125
# 2             bpe  perplexity  31923.374072
# 3      bpe_custom  perplexity  14370.876125
# 4         unigram  perplexity  28572.977656
# 5  unigram_custom  perplexity  12245.680986
